# %% [markdown]
# ---
# # <span style="color:purple"> CLEANSING DATA </span>
# ---

# %% [markdown]
# ## <span style="color:purple"> Inisiasi </span>

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = 'ugm2018'
database = 'gdelt2'

table_name = 'events_LA'
fips_country_code = 'LA'
country_code = 'LAO'
# BRN, KHM, LAO, IDN, MYS, VNM, THA, SGP, PHL, MMR

conn_str = 'mysql+pymysql://{}:{}@{}:{}/{}'.format(user, password, host, port, database);           
engine = create_engine(conn_str)

def run(sql):
    df = pd.read_sql_query(sql,engine)
    return df

def execute(sql):
    return engine.execute(statement=sql)

# %% [markdown]
# ### <span style="color:purple"> Cleansing Strategy </span>
# - Observe Events by year
# - Make sure date in range of 2003-2017
# - Filter by Actor1CountryCode or Actor2CountryCode
# - Deduplicate SOURCEURL (contained http/https)
# - For null SOURCEURL and non http source, deduplicate news by theirs similiarities (AvgTone, ActionGeoLat, ActionGeoLong, GoldSteinScale, EventCode)
#
# ****

# %% [markdown]
# ### a. Get Total News (Before Cleansing)
# ___

# %%
total_news = run("""
SELECT         
    count(GLOBALEVENTID) as count 
FROM {} 
""".format(table_name))

print('Total News :', total_news['count'][0])
# Out:
# Total News : 1913966

# %% [markdown]
# ### b. Make sure date in range of 2003-2017
# ___

# %% [markdown]
# #### 1. Preview

# %%
out_of_range_counter = run("""
select count(GLOBALEVENTID) as count from {} where Year < 2003 or Year > 2017
""".format(table_name))

print('Out of Range :', out_of_range_counter['count'][0])
# Out:
# Out of Range : 285891

# %% [markdown]
# #### 2. Execute Deletion

# %%
execute("""
delete from {} where Year < 2003 or Year > 2017
""".format(table_name))

total_news = run("""
SELECT         
    count(GLOBALEVENTID) as count 
FROM {} 
""".format(table_name))

print('Total News Now:', total_news['count'][0])
# Out:
# Total News Now: 1628075

# %% [markdown]
# ### c. Filter by Actor1CountryCode or Actor2CountryCode
# ---

# %% [markdown]
# #### 1. Preview

# %%
data = run("""
select GLOBALEVENTID, SOURCEURL, Actor1CountryCode, Actor2CountryCode 
from {} WHERE Actor1CountryCode <> '{}' AND Actor2CountryCode <> '{}'
""".format(table_name, country_code, country_code))

data

# %% [markdown]
# #### 2. Execute Deletion

# %%
execute("""
delete from {} WHERE Actor1CountryCode <> '{}' AND Actor2CountryCode <> '{}'
""".format(table_name, country_code, country_code))

total_news = run("""
SELECT         
    count(GLOBALEVENTID) as count 
FROM {} 
""".format(table_name))

print('Total News Now:', total_news['count'][0])
# Out:
# Total News Now: 872095

# %% [markdown]
# ### d. Deduplicate by SOURCEURL (contained http or https )
# ----

# %% [markdown]
# #### 1. Preview

# %%
duplicateURL = run("""
SELECT t1.GLOBALEVENTID, t1.SOURCEURL, t1.NumArticles,
  ROW_NUMBER() OVER(PARTITION BY t1.SOURCEURL ORDER BY t1.SOURCEURL, t1.NumArticles DESC) AS DuplicateCount
  FROM {} t1
  WHERE t1.SOURCEURL like 'http://%%' OR t1.SOURCEURL LIKE 'https://%%'  
  
  """.format(table_name))

duplicateURL
# Out:
#         GLOBALEVENTID                                          SOURCEURL  \
# 0           422165081  http://02elf.net/allgemein/evorich-flooring-on...
# 1           328639598  http://02elf.net/allgemein/media-release-austr...
# 2           422187573  http://02elf.net/allgemein/montreal-long-dista...
# 3           481587263  http://0lf.net/2015/11/03/sisi-looking-with-th...
# 4           464237099  http://0lf.net/newspapers-cairo-results-sisi-r...
# 5           464237097  http://0lf.net/newspapers-cairo-results-sisi-r...
# 6           464237102  http://0lf.net/newspapers-cairo-results-sisi-r...
# 7           464237098  http://0lf.net/newspapers-cairo-results-sisi-r...
# 8           462209321  http://0lf.net/sisi-up-singapore-at-the-start-...
# 9           462209323  http://0lf.net/sisi-up-singapore-at-the-start-...
# 10          462209324  http://0lf.net/sisi-up-singapore-at-the-start-...
# 11          497813460  http://1001concert.ru/article/applecare+iphone...
# 12          499222791  http://100freeclassifieds.com/free-car-wash-an...
# 13          475269881  http://100plasticsurgery.blogspot.com/2015/10/...
# 14          475270644  http://100plasticsurgery.blogspot.com/2015/10/...
# 15          600285342  http://100pour100-velo.com/2016/11/18/united-k...
# 16          600285344  http://100pour100-velo.com/2016/11/18/united-k...
# 17          600285678  http://100pour100-velo.com/2016/11/18/united-k...
# 18          600285681  http://100pour100-velo.com/2016/11/18/united-k...
# 19          600285960  http://100pour100-velo.com/2016/11/18/united-k...
# 20          600285962  http://100pour100-velo.com/2016/11/18/united-k...
# 21          600285965  http://100pour100-velo.com/2016/11/18/united-k...
# 22          600285968  http://100pour100-velo.com/2016/11/18/united-k...
# 23          600285679  http://100pour100-velo.com/2016/11/18/united-k...
# 24          600285682  http://100pour100-velo.com/2016/11/18/united-k...
# 25          600285964  http://100pour100-velo.com/2016/11/18/united-k...
# 26          600285967  http://100pour100-velo.com/2016/11/18/united-k...
# 27          605537953  http://100pour100-velo.com/2016/12/05/malaysia...
# 28          605537954  http://100pour100-velo.com/2016/12/05/malaysia...
# 29          605396354  http://100pour100-velo.com/2016/12/05/rohingya...
# ...               ...                                                ...
# 580059      586530765  https://zimnews.net/latest-news-mugabe-flies-t...
# 580060      633884924  https://zimnews.net/mugabe-flies-ghana-defends...
# 580061      610375823  https://zimnews.net/mugabe-grace-family-bona-s...
# 580062      610378513  https://zimnews.net/mugabe-grace-family-bona-s...
# 580063      588807884  https://zimnews.net/mugabe-meets-mnangagwa-dis...
# 580064      588808459  https://zimnews.net/mugabe-meets-mnangagwa-dis...
# 580065      588807883  https://zimnews.net/mugabe-meets-mnangagwa-dis...
# 580066      588808457  https://zimnews.net/mugabe-meets-mnangagwa-dis...
# 580067      588807882  https://zimnews.net/mugabe-meets-mnangagwa-dis...
# 580068      588808456  https://zimnews.net/mugabe-meets-mnangagwa-dis...
# 580069      636942958  https://zimnews.net/mugabe-money-for-cyclone-d...
# 580070      615047527  https://zimnews.net/picture-mnangagwa-takes-mu...
# 580071      638730192  https://zimnews.net/president-mugabe-dumps-his...
# 580072      638730814  https://zimnews.net/president-mugabe-dumps-his...
# 580073      655255190  https://zimnews.net/president-mugabe-leaves-si...
# 580074      655255189  https://zimnews.net/president-mugabe-leaves-si...
# 580075      673167277  https://zimnews.net/tsvangirai-falls-ill-rushe...
# 580076      673167288  https://zimnews.net/tsvangirai-falls-ill-rushe...
# 580077      673167290  https://zimnews.net/tsvangirai-falls-ill-rushe...
# 580078      673167276  https://zimnews.net/tsvangirai-falls-ill-rushe...
# 580079      673167287  https://zimnews.net/tsvangirai-falls-ill-rushe...
# 580080      673167289  https://zimnews.net/tsvangirai-falls-ill-rushe...
# 580081      659484723  https://zimnews.net/zim-pres-angry-over-mexico...
# 580082      586648562  https://zimnews.net/zim-pres-mugabe-grace-bona...
# 580083      586648566  https://zimnews.net/zim-pres-mugabe-grace-bona...
# 580084      586650233  https://zimnews.net/zim-pres-mugabe-grace-bona...
# 580085      671192143  https://zizonline.com/st-kitts-and-nevis-annou...
# 580086      671194226  https://zizonline.com/st-kitts-and-nevis-annou...
# 580087      718435414          https://zwnews.com/update-is-mugabe-dead/
# 580088      718436482          https://zwnews.com/update-is-mugabe-dead/
#
#         NumArticles  DuplicateCount
# 0                10               1
# 1                 4               1
# 2                 9               1
# 3                 2               1
# 4                 6               1
# 5                 3               2
# 6                 3               3
# 7                 1               4
# 8                 1               1
# 9                 1               2
# 10                1               3
# 11               14               1
# 12                2               1
# 13                3               1
# 14                3               2
# 15                6               1
# 16                6               2
# 17                6               3
# 18                6               4
# 19                6               5
# 20                6               6
# 21                6               7
# 22                6               8
# 23                2               9
# 24                2              10
# 25                2              11
# 26                2              12
# 27                6               1
# 28                2               2
# 29                2               1
# ...             ...             ...
# 580059            2               3
# 580060           62               1
# 580061           10               1
# 580062           10               2
# 580063           10               1
# 580064           10               2
# 580065            2               3
# 580066            2               4
# 580067            1               5
# 580068            1               6
# 580069            5               1
# 580070            4               1
# 580071           10               1
# 580072           10               2
# 580073            4               1
# 580074            1               2
# 580075            8               1
# 580076            8               2
# 580077            8               3
# 580078            2               4
# 580079            2               5
# 580080            2               6
# 580081           10               1
# 580082           10               1
# 580083           10               2
# 580084            4               3
# 580085            4               1
# 580086            4               2
# 580087           10               1
# 580088           10               2
#
# [580089 rows x 4 columns]

# %% [markdown]
# #### 2. Execute Deletion

# %%
execute("""
 DELETE FROM {}
 WHERE GLOBALEVENTID in (
 (SELECT t2.GLOBALEVENTID
 FROM
 (SELECT t1.GLOBALEVENTID, t1.SOURCEURL,  
  ROW_NUMBER() OVER(PARTITION BY t1.SOURCEURL ORDER BY t1.SOURCEURL, t1.NumArticles DESC) AS DuplicateCount
  FROM {} t1
  WHERE t1.SOURCEURL like 'http://%%' OR t1.SOURCEURL LIKE 'https://%%'
    ) t2
  WHERE t2.DuplicateCount > 1)
  )
 """.format(table_name, table_name))

total_news = run("""
SELECT         
    count(GLOBALEVENTID) as count 
FROM {} 
""".format(table_name,table_name))

print('Total News Now:', total_news['count'][0])
# Out:
# Total News Now: 516507

# %% [markdown]
# ### d. Deduplicate by SOURCEURL (other than contained http or https )
# ----
# Key: Have similarities in SQLDATE, AvgTone, ActionGeoLat, ActionGeoLong, GoldSteinScale, EventCode

# %% [markdown]
# #### 1. Preview

# %%
duplicateURL2 = run("""
SELECT t1.GLOBALEVENTID, t1.NumArticles, t1.SOURCEURL, t1.SQLDATE,t1.AvgTone, t1.ActionGeo_Lat, t1.ActionGeo_Long,
  ROW_NUMBER() OVER(PARTITION BY t1.SQLDATE,t1.AvgTone, t1.ActionGeo_Lat, t1.ActionGeo_Long
  ORDER BY t1.SQLDATE, t1.AvgTone, t1.NumArticles DESC) AS DuplicateCount
  FROM {} t1  
  WHERE t1.SOURCEURL not like '%%http://%%' OR t1.SOURCEURL not LIKE '%%https://%%'
  """.format(table_name))

duplicateURL2
# Out:
#         GLOBALEVENTID  NumArticles  \
# 0            44569065            9
# 1            44569075            9
# 2            44569066            9
# 3            44562533            2
# 4            44569072            2
# 5            44569080           18
# 6            44569079            4
# 7            44569069            2
# 8            44569073            9
# 9            44562532            2
# 10           44569068            2
# 11           44569074            2
# 12           44568742           18
# 13           44569081           18
# 14           44569076            9
# 15           44569077            9
# 16           44569078            9
# 17           44577521            4
# 18           44579137            4
# 19           44579130            3
# 20           44579132            3
# 21           44573002            2
# 22           44579131            1
# 23           44579133            1
# 24           44579147            1
# 25           44577609            9
# 26           44579134            3
# 27           44577607            5
# 28           44579139            1
# 29           44579143            1
# ...               ...          ...
# 511987      718896747           10
# 511988      718945393           10
# 511989      718882681           66
# 511990      718980211            1
# 511991      718907546           32
# 511992      718888099            3
# 511993      719022370            5
# 511994      718926920            6
# 511995      718926918            5
# 511996      718891194           16
# 511997      718954896           10
# 511998      718896745           25
# 511999      718920752          183
# 512000      718923832           20
# 512001      718951645            2
# 512002      718946880           30
# 512003      718989052           10
# 512004      718948420           10
# 512005      718915672            8
# 512006      718982015            4
# 512007      718896324            5
# 512008      718908795           10
# 512009      719015441            2
# 512010      718913690           20
# 512011      726750240            8
# 512012      718983248            8
# 512013      719001903           10
# 512014      718941570           16
# 512015      719001547           40
# 512016      719001546            8
#
#                                                 SOURCEURL   SQLDATE  \
# 0                                                     n/a  20030101
# 1                                                     n/a  20030101
# 2                                                     n/a  20030101
# 3                                                     n/a  20030101
# 4                                                     n/a  20030101
# 5                                                     n/a  20030101
# 6                                                     n/a  20030101
# 7                                                     n/a  20030101
# 8                                                     n/a  20030101
# 9                                                     n/a  20030101
# 10                                                    n/a  20030101
# 11                                                    n/a  20030101
# 12                                                    n/a  20030101
# 13                                                    n/a  20030101
# 14                                                    n/a  20030101
# 15                                                    n/a  20030101
# 16                                                    n/a  20030101
# 17                                                    n/a  20030102
# 18                                                    n/a  20030102
# 19                                                    n/a  20030102
# 20                                                    n/a  20030102
# 21                                                    n/a  20030102
# 22                                                    n/a  20030102
# 23                                                    n/a  20030102
# 24                                                    n/a  20030102
# 25                                                    n/a  20030102
# 26                                                    n/a  20030102
# 27                                                    n/a  20030102
# 28                                                    n/a  20030102
# 29                                                    n/a  20030102
# ...                                                   ...       ...
# 511987  http://www.themalaymailonline.com/opinion/sure...  20171231
# 511988  http://www.straitstimes.com/politics/plans-to-...  20171231
# 511989  https://international.thenewslens.com/article/...  20171231
# 511990  http://www.thehindu.com/news/national/tamil-na...  20171231
# 511991  http://www.channelnewsasia.com/news/singapore/...  20171231
# 511992  http://en.republika.co.id/berita/en/national-p...  20171231
# 511993  http://www.channelnewsasia.com/news/lifestyle/...  20171231
# 511994  https://www.expressandstar.com/news/local-hubs...  20171231
# 511995  http://worldtribunepakistan.com/2017/12/31/sin...  20171231
# 511996  http://www.straitstimes.com/lifestyle/count-do...  20171231
# 511997  https://www.theborneopost.com/2017/12/31/singa...  20171231
# 511998  http://www.straitstimes.com/lifestyle/food/the...  20171231
# 511999  http://www.dailymail.co.uk/wires/afp/article-5...  20171231
# 512000  http://en.rfi.fr/wire/20171231-singapore-bar-o...  20171231
# 512001  http://www.france24.com/en/20171231-singapore-...  20171231
# 512002  http://www.pmo.gov.sg/newsroom/2018-new-year-m...  20171231
# 512003  https://mothership.sg/2017/12/singapore-bicent...  20171231
# 512004  http://www.channelnewsasia.com/news/singapore/...  20171231
# 512005  http://sgblogs.com/pages/107584652-airasia-now...  20171231
# 512006  https://tenplay.com.au/channel-ten/joseph-prin...  20171231
# 512007  http://www.straitstimes.com/singapore/lunch-wi...  20171231
# 512008  http://sglinks.com/pages/107568207-singapore-k...  20171231
# 512009  http://sglinks.com/pages/107605497-ring-in-the...  20171231
# 512010  https://www.msn.com/en-in/news/other/new-year-...  20171231
# 512011  http://www.gdnonline.com/Details/305376/UAE-de...  20171231
# 512012  http://indiatoday.intoday.in/story/new-year-20...  20171231
# 512013  http://aviationweek.com/awin-only/jet-aviation...  20171231
# 512014  http://www.channelnewsasia.com/news/singapore/...  20171231
# 512015  https://www.themorningbulletin.com.au/news/liv...  20171231
# 512016  https://www.skynews.com.au/details/_5699127353001  20171231
#
#                   AvgTone ActionGeo_Lat ActionGeo_Long  DuplicateCount
# 0        2.98507462686567        1.3667          103.8               1
# 1        2.98507462686567        1.3667          103.8               2
# 2        5.54279149913843        1.3667          103.8               1
# 3        6.19469026548673        1.3667          103.8               1
# 4        6.19469026548673        1.3667          103.8               2
# 5          6.259995735153        1.3667          103.8               1
# 6        6.25999573515301        1.3667          103.8               1
# 7        6.32530120481928        1.3667          103.8               1
# 8        6.32530120481928            35            105               1
# 9        6.32530120481928            35            105               2
# 10       6.32530120481928            35            105               3
# 11       7.05882352941176       19.4355        144.888               1
# 12       7.69961977186312        1.3667          103.8               1
# 13       7.69961977186312        1.3667          103.8               2
# 14        9.1644204851752        1.3667          103.8               1
# 15        9.1644204851752        1.3667          103.8               2
# 16        9.1644204851752        1.3667          103.8               3
# 17       3.52941176470588        1.3667          103.8               1
# 18       3.52941176470588        1.3667          103.8               2
# 19       3.52941176470588        1.3667          103.8               3
# 20       3.52941176470588        1.3667          103.8               4
# 21       3.52941176470588        1.3667          103.8               5
# 22       3.52941176470588        1.3667          103.8               6
# 23       3.52941176470588        1.3667          103.8               7
# 24       3.52941176470588        1.3667          103.8               8
# 25       4.36507936507936        1.3667          103.8               1
# 26       4.40097799511002       1.33028        104.408               1
# 27       4.85981308411215        1.3667          103.8               1
# 28       4.85981308411215        1.3667          103.8               2
# 29       4.85981308411215        1.3667          103.8               3
# ...                   ...           ...            ...             ...
# 511987   0.11025358324145       1.43333        103.831               1
# 511988    0.3076923076923      1.366667          103.8               1
# 511989  0.646892031365922      1.366667          103.8               1
# 511990   0.67796610169491           9.7        78.4833               1
# 511991  0.700813333942994      1.366667          103.8               1
# 511992  0.710900473933651      1.366667          103.8               1
# 511993   0.71355759429154       1.28694        103.831               1
# 511994   0.73421439060206      1.366667          103.8               1
# 511995   0.80971659919028      1.366667          103.8               1
# 511996   1.19949494949495       1.28389        103.858               1
# 511997   1.29032258064516      1.366667          103.8               1
# 511998   1.29350963590089      1.366667          103.8               1
# 511999   1.33234917869594      1.366667          103.8               1
# 512000   1.36111111111111      1.366667          103.8               1
# 512001   1.38888888888889      1.366667          103.8               1
# 512002   1.49972592069822       1.34167        103.964               1
# 512003   1.60183066361556      1.366667          103.8               1
# 512004   1.73410404624277       1.34167        103.964               1
# 512005   1.92307692307692      1.366667          103.8               1
# 512006   10.3448275862069      1.366667          103.8               1
# 512007   2.15169445938677       1.34167        103.964               1
# 512008   2.19435736677116      1.366667          103.8               1
# 512009   2.51141552511416      1.366667          103.8               1
# 512010   2.57967014422753       1.25333        103.813               1
# 512011   2.60869565217391       3.16667          101.7               1
# 512012   3.36391437308869      -33.8833        151.217               1
# 512013   3.48837209302326          1.41        103.874               1
# 512014    3.7037037037037      1.366667          103.8               1
# 512015   4.21075997611698      1.366667          103.8               1
# 512016              5.625            35            105               1
#
# [512017 rows x 8 columns]

# %% [markdown]
# #### 2. Execute Deletion

# %%
execute("""
 DELETE FROM {}
 WHERE GLOBALEVENTID in (
 (SELECT t2.GLOBALEVENTID
 FROM
 (SELECT t1.GLOBALEVENTID,
  ROW_NUMBER() OVER(PARTITION BY t1.SQLDATE, t1.AvgTone, t1.ActionGeo_Lat, t1.ActionGeo_Long, t1.SOURCEURL
  ORDER BY t1.SQLDATE, t1.AvgTone, t1.NumArticles DESC) AS DuplicateCount
  FROM {} t1 WHERE t1.SOURCEURL not like 'http://%%' OR t1.SOURCEURL not LIKE 'https://%%') t2
  WHERE t2.DuplicateCount > 1)
  )
 """.format(table_name, table_name))

total_news = run("""
SELECT         
    count(GLOBALEVENTID) as count 
FROM {} 
""".format(table_name,table_name))

print('Total News Now:', total_news['count'][0])
# Out:
# Total News Now: 370718

# %% [markdown]
# ### f. Get Total News (After Cleansing)
# ___

# %%
total_news = run("""
SELECT         
    count(GLOBALEVENTID) as count 
FROM {} 
""".format(table_name))

print('Total News :', total_news['count'][0])
# Out:
# Total News : 370718

# %% [markdown]
# ---
# # <span style="color:purple"> REKAP DATA </span>
# ---

# %% [markdown]
# #### 1. Overview Result

# %%
overviewResult = run("""
SELECT 
    Year, 
    count(a.GLOBALEVENTID) as `Total Events`     
FROM {} a GROUP BY Year ORDER BY Year
  """.format(table_name))

overviewResult
# Out:
#     Year  Total Events
# 0   2003          5272
# 1   2004          3748
# 2   2005          3202
# 3   2006          5502
# 4   2007          9927
# 5   2008         12120
# 6   2009         22541
# 7   2010         20164
# 8   2011         26774
# 9   2012         28202
# 10  2013         28208
# 11  2014         35281
# 12  2015         57780
# 13  2016         62403
# 14  2017         49594

# %% [markdown]
# #### 2. Rekap Event

# %%
event = run("""
SELECT         
    Year, 
    CONCAT(EventCode,'. ',(SELECT description FROM CAMEO_events_code WHERE code = EventCode)) as Description,
    count(GLOBALEVENTID) as Jumlah
FROM {} 
WHERE Year > 2002
GROUP BY EventCode, Year
  """.format(table_name))

event.pivot(index='Description', columns='Year', values='Jumlah')
# Out:
# Year                                                 2003   2004   2005  \
# Description
# 010. Make statement, not specified below            376.0  264.0  265.0
# 011. Decline comment                                  8.0    8.0    9.0
# 012. Make pessimistic comment                        65.0   54.0   40.0
# 013. Make optimistic comment                        102.0   83.0   56.0
# 014. Consider policy option                          31.0   22.0   29.0
# 015. Acknowledge or claim responsibility             10.0   18.0    9.0
# 016. Deny responsibility                             15.0    5.0    9.0
# 017. Engage in symbolic act                          10.0   16.0   14.0
# 018. Make empathetic comment                         14.0    9.0   15.0
# 019. Express accord                                   1.0    NaN    NaN
# 020. Make an appeal or request, not specified b...  286.0  168.0  172.0
# 021. Appeal for material cooperation, not speci...    1.0    NaN    NaN
# 0211. Appeal for economic cooperation                 1.0    2.0    3.0
# 0213. Appeal for judicial cooperation                 5.0    1.0    1.0
# 0214. Appeal for intelligence                         NaN    2.0    2.0
# 022. Appeal for diplomatic cooperation (such as...    9.0    7.0    4.0
# 023. Appeal for aid, not specified below              1.0    NaN    5.0
# 0231. Appeal for economic aid                         3.0    2.0    5.0
# 0232. Appeal for military aid                         1.0    NaN    NaN
# 0233. Appeal for humanitarian aid                     NaN    NaN    NaN
# 0234. Appeal for military protection or peaceke...    NaN    NaN    4.0
# 024. Appeal for political reform, not specified...    1.0    NaN    1.0
# 0241. Appeal for change in leadership                 NaN    NaN    NaN
# 0242. Appeal for policy change                        NaN    NaN    NaN
# 0243. Appeal for rights                               NaN    NaN    NaN
# 0244. Appeal for change in institutions, regime       NaN    NaN    NaN
# 025. Appeal to yield, not specified below            11.0    7.0   12.0
# 0251. Appeal for easing of administrative sanct...    NaN    NaN    2.0
# 0253. Appeal for release of persons or property       NaN    2.0    1.0
# 0254. Appeal for easing of economic sanctions, ...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# 1711. Confiscate property                             7.0    2.0    NaN
# 1712. Destroy property                                NaN    2.0    NaN
# 172. Impose administrative sanctions, not speci...   44.0   35.0   25.0
# 1721. Impose restrictions on political freedoms       7.0    8.0    NaN
# 1722. Ban political parties or politicians            NaN    1.0    NaN
# 1723. Impose curfew                                   NaN    NaN    NaN
# 1724. Impose state of emergency or martial law        NaN    NaN    NaN
# 173. Arrest, detain, or charge with legal action    292.0  143.0  191.0
# 174. Expel or deport individuals                      7.0    3.0    7.0
# 175. Use tactics of violent repression                2.0    NaN    NaN
# 180. Use unconventional violence, not specified...    8.0    2.0    6.0
# 181. Abduct, hijack, or take hostage                  3.0   10.0    3.0
# 182. Physically assault, not specified below          6.0    4.0    1.0
# 1821. Sexually assault                                2.0    NaN    NaN
# 1822. Torture                                         1.0    NaN    NaN
# 1823. Kill by physical assault                        NaN    NaN    NaN
# 183. Conduct suicide, car, or other non-militar...    2.0    1.0    2.0
# 1831. Carry out suicide bombing                       2.0    NaN    NaN
# 1832. Carry out vehicular bombing                     NaN    NaN    NaN
# 185. Attempt to assassinate                           NaN    NaN    NaN
# 186. Assassinate                                      6.0   11.0   12.0
# 190. Use conventional military force, not speci...   93.0   48.0   63.0
# 191. Impose blockade, restrict movement               2.0    1.0    2.0
# 192. Occupy territory                                13.0    1.0    2.0
# 193. Fight with small arms and light weapons          9.0    6.0    7.0
# 194. Fight with artillery and tanks                   6.0    4.0    6.0
# 195. Employ aerial weapons, not specified below       3.0    2.0    1.0
# 201. Engage in mass expulsion                         NaN    NaN    NaN
# 202. Engage in mass killings                          NaN    NaN    NaN
# 203. Engage in ethnic cleansing                       NaN    NaN    NaN
#
# Year                                                 2006   2007   2008  \
# Description
# 010. Make statement, not specified below            431.0  836.0  998.0
# 011. Decline comment                                 11.0   28.0   10.0
# 012. Make pessimistic comment                        89.0  177.0  166.0
# 013. Make optimistic comment                        129.0  217.0  297.0
# 014. Consider policy option                          71.0   98.0   97.0
# 015. Acknowledge or claim responsibility             20.0   19.0   54.0
# 016. Deny responsibility                             12.0   30.0   15.0
# 017. Engage in symbolic act                          22.0   62.0   32.0
# 018. Make empathetic comment                          5.0   20.0   49.0
# 019. Express accord                                   1.0    1.0    3.0
# 020. Make an appeal or request, not specified b...  294.0  506.0  649.0
# 021. Appeal for material cooperation, not speci...    1.0    4.0    4.0
# 0211. Appeal for economic cooperation                 2.0    7.0    6.0
# 0213. Appeal for judicial cooperation                 1.0    3.0    NaN
# 0214. Appeal for intelligence                         2.0    1.0   12.0
# 022. Appeal for diplomatic cooperation (such as...    2.0    4.0    8.0
# 023. Appeal for aid, not specified below              NaN    9.0   14.0
# 0231. Appeal for economic aid                         8.0   12.0    8.0
# 0232. Appeal for military aid                         NaN    NaN    1.0
# 0233. Appeal for humanitarian aid                     NaN    NaN    NaN
# 0234. Appeal for military protection or peaceke...    3.0    2.0    3.0
# 024. Appeal for political reform, not specified...    NaN    NaN    NaN
# 0241. Appeal for change in leadership                 1.0    NaN    NaN
# 0242. Appeal for policy change                        NaN    NaN    NaN
# 0243. Appeal for rights                               NaN    NaN    NaN
# 0244. Appeal for change in institutions, regime       NaN    NaN    NaN
# 025. Appeal to yield, not specified below            11.0   28.0   33.0
# 0251. Appeal for easing of administrative sanct...    NaN    NaN    NaN
# 0253. Appeal for release of persons or property       1.0    3.0    3.0
# 0254. Appeal for easing of economic sanctions, ...    NaN    NaN    NaN
# ...                                                   ...    ...    ...
# 1711. Confiscate property                             6.0    3.0    3.0
# 1712. Destroy property                                3.0    8.0    7.0
# 172. Impose administrative sanctions, not speci...   77.0  118.0  152.0
# 1721. Impose restrictions on political freedoms       8.0   14.0    7.0
# 1722. Ban political parties or politicians            2.0    NaN    1.0
# 1723. Impose curfew                                   1.0    3.0    3.0
# 1724. Impose state of emergency or martial law        NaN    NaN    NaN
# 173. Arrest, detain, or charge with legal action    213.0  251.0  462.0
# 174. Expel or deport individuals                     17.0   18.0   14.0
# 175. Use tactics of violent repression                NaN    NaN    1.0
# 180. Use unconventional violence, not specified...    7.0   10.0   19.0
# 181. Abduct, hijack, or take hostage                  1.0    1.0   12.0
# 182. Physically assault, not specified below          4.0    6.0   14.0
# 1821. Sexually assault                                NaN    3.0    4.0
# 1822. Torture                                         NaN    3.0    NaN
# 1823. Kill by physical assault                        3.0    NaN    2.0
# 183. Conduct suicide, car, or other non-militar...    NaN    1.0    1.0
# 1831. Carry out suicide bombing                       NaN    NaN    NaN
# 1832. Carry out vehicular bombing                     NaN    NaN    NaN
# 185. Attempt to assassinate                           NaN    NaN    1.0
# 186. Assassinate                                      1.0    5.0    4.0
# 190. Use conventional military force, not speci...   71.0  107.0  181.0
# 191. Impose blockade, restrict movement               1.0    3.0    2.0
# 192. Occupy territory                                12.0   34.0   32.0
# 193. Fight with small arms and light weapons          9.0   28.0   22.0
# 194. Fight with artillery and tanks                   1.0    3.0    4.0
# 195. Employ aerial weapons, not specified below       1.0    5.0    NaN
# 201. Engage in mass expulsion                         NaN    NaN    NaN
# 202. Engage in mass killings                          NaN    NaN    NaN
# 203. Engage in ethnic cleansing                       NaN    NaN    NaN
#
# Year                                                  2009    2010    2011  \
# Description
# 010. Make statement, not specified below            1697.0  1688.0  2478.0
# 011. Decline comment                                  35.0    46.0    47.0
# 012. Make pessimistic comment                        410.0   321.0   430.0
# 013. Make optimistic comment                         535.0   474.0   593.0
# 014. Consider policy option                          221.0   170.0   292.0
# 015. Acknowledge or claim responsibility              77.0   114.0   104.0
# 016. Deny responsibility                              27.0    24.0    48.0
# 017. Engage in symbolic act                          116.0   147.0   152.0
# 018. Make empathetic comment                          49.0    78.0    48.0
# 019. Express accord                                    1.0     NaN     4.0
# 020. Make an appeal or request, not specified b...  1266.0  1166.0  1813.0
# 021. Appeal for material cooperation, not speci...     5.0     2.0     1.0
# 0211. Appeal for economic cooperation                  6.0     6.0    15.0
# 0213. Appeal for judicial cooperation                  1.0     3.0    17.0
# 0214. Appeal for intelligence                          7.0     7.0     4.0
# 022. Appeal for diplomatic cooperation (such as...    20.0     8.0    29.0
# 023. Appeal for aid, not specified below              25.0    19.0    26.0
# 0231. Appeal for economic aid                         14.0    20.0    14.0
# 0232. Appeal for military aid                          1.0     NaN     2.0
# 0233. Appeal for humanitarian aid                      4.0     1.0     2.0
# 0234. Appeal for military protection or peaceke...     1.0     4.0     1.0
# 024. Appeal for political reform, not specified...     NaN     NaN     NaN
# 0241. Appeal for change in leadership                  NaN     4.0     4.0
# 0242. Appeal for policy change                         NaN     NaN     2.0
# 0243. Appeal for rights                                NaN     NaN     NaN
# 0244. Appeal for change in institutions, regime        NaN     NaN     NaN
# 025. Appeal to yield, not specified below             20.0    42.0    53.0
# 0251. Appeal for easing of administrative sanct...     NaN     NaN     1.0
# 0253. Appeal for release of persons or property       17.0     3.0     1.0
# 0254. Appeal for easing of economic sanctions, ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# 1711. Confiscate property                              1.0     9.0     6.0
# 1712. Destroy property                                16.0    79.0    14.0
# 172. Impose administrative sanctions, not speci...   219.0   166.0   225.0
# 1721. Impose restrictions on political freedoms        4.0     6.0     9.0
# 1722. Ban political parties or politicians             1.0     3.0     2.0
# 1723. Impose curfew                                    6.0     5.0     8.0
# 1724. Impose state of emergency or martial law         NaN     NaN     NaN
# 173. Arrest, detain, or charge with legal action     729.0   799.0   800.0
# 174. Expel or deport individuals                      39.0    11.0    27.0
# 175. Use tactics of violent repression                 3.0     2.0     1.0
# 180. Use unconventional violence, not specified...    36.0    29.0    31.0
# 181. Abduct, hijack, or take hostage                  20.0     7.0    14.0
# 182. Physically assault, not specified below          31.0    13.0    34.0
# 1821. Sexually assault                                 4.0    22.0    10.0
# 1822. Torture                                          1.0     4.0     4.0
# 1823. Kill by physical assault                         3.0     2.0     3.0
# 183. Conduct suicide, car, or other non-militar...     2.0    14.0     2.0
# 1831. Carry out suicide bombing                        1.0     1.0     NaN
# 1832. Carry out vehicular bombing                      NaN     NaN     NaN
# 185. Attempt to assassinate                            NaN     NaN     NaN
# 186. Assassinate                                      33.0    10.0    47.0
# 190. Use conventional military force, not speci...   300.0   254.0   367.0
# 191. Impose blockade, restrict movement                6.0     5.0     9.0
# 192. Occupy territory                                 63.0    56.0    50.0
# 193. Fight with small arms and light weapons          78.0    71.0    85.0
# 194. Fight with artillery and tanks                    7.0     2.0     5.0
# 195. Employ aerial weapons, not specified below       10.0     7.0     8.0
# 201. Engage in mass expulsion                          NaN     NaN     NaN
# 202. Engage in mass killings                           NaN     NaN     NaN
# 203. Engage in ethnic cleansing                        NaN     NaN     1.0
#
# Year                                                  2012    2013    2014  \
# Description
# 010. Make statement, not specified below            2307.0  2299.0  2896.0
# 011. Decline comment                                  38.0    35.0    42.0
# 012. Make pessimistic comment                        385.0   460.0   514.0
# 013. Make optimistic comment                         552.0   547.0   681.0
# 014. Consider policy option                          281.0   280.0   323.0
# 015. Acknowledge or claim responsibility             134.0   114.0   168.0
# 016. Deny responsibility                              72.0    61.0    33.0
# 017. Engage in symbolic act                          165.0   228.0   275.0
# 018. Make empathetic comment                          80.0    80.0    71.0
# 019. Express accord                                   10.0     5.0     6.0
# 020. Make an appeal or request, not specified b...  1877.0  1720.0  2366.0
# 021. Appeal for material cooperation, not speci...     7.0     5.0     3.0
# 0211. Appeal for economic cooperation                 15.0    11.0     7.0
# 0213. Appeal for judicial cooperation                  3.0     2.0     1.0
# 0214. Appeal for intelligence                         10.0    22.0    16.0
# 022. Appeal for diplomatic cooperation (such as...    25.0    20.0    28.0
# 023. Appeal for aid, not specified below              31.0    35.0    50.0
# 0231. Appeal for economic aid                         18.0    19.0    38.0
# 0232. Appeal for military aid                          3.0     2.0     4.0
# 0233. Appeal for humanitarian aid                      NaN     1.0     3.0
# 0234. Appeal for military protection or peaceke...     8.0     6.0     7.0
# 024. Appeal for political reform, not specified...     NaN     NaN     6.0
# 0241. Appeal for change in leadership                 11.0     3.0     7.0
# 0242. Appeal for policy change                         NaN     NaN     NaN
# 0243. Appeal for rights                                2.0     NaN     1.0
# 0244. Appeal for change in institutions, regime        NaN     1.0     NaN
# 025. Appeal to yield, not specified below             34.0    55.0    28.0
# 0251. Appeal for easing of administrative sanct...     NaN     NaN     NaN
# 0253. Appeal for release of persons or property        NaN     1.0     3.0
# 0254. Appeal for easing of economic sanctions, ...     1.0     NaN     NaN
# ...                                                    ...     ...     ...
# 1711. Confiscate property                              7.0     5.0     4.0
# 1712. Destroy property                                30.0    36.0    37.0
# 172. Impose administrative sanctions, not speci...   284.0   349.0   483.0
# 1721. Impose restrictions on political freedoms        6.0    12.0    13.0
# 1722. Ban political parties or politicians             3.0     6.0     NaN
# 1723. Impose curfew                                    7.0     1.0     9.0
# 1724. Impose state of emergency or martial law         NaN     NaN     3.0
# 173. Arrest, detain, or charge with legal action     935.0   975.0  1042.0
# 174. Expel or deport individuals                      51.0    26.0    24.0
# 175. Use tactics of violent repression                 2.0     3.0     1.0
# 180. Use unconventional violence, not specified...    93.0   103.0    46.0
# 181. Abduct, hijack, or take hostage                  37.0     6.0    25.0
# 182. Physically assault, not specified below          54.0    57.0    82.0
# 1821. Sexually assault                               261.0   115.0    20.0
# 1822. Torture                                         13.0     9.0     4.0
# 1823. Kill by physical assault                         5.0     1.0    16.0
# 183. Conduct suicide, car, or other non-militar...     3.0     NaN     8.0
# 1831. Carry out suicide bombing                        1.0     NaN     2.0
# 1832. Carry out vehicular bombing                      NaN     NaN     NaN
# 185. Attempt to assassinate                            NaN     NaN     NaN
# 186. Assassinate                                      35.0    40.0    32.0
# 190. Use conventional military force, not speci...   463.0   511.0   604.0
# 191. Impose blockade, restrict movement               25.0    17.0    14.0
# 192. Occupy territory                                 72.0    90.0   203.0
# 193. Fight with small arms and light weapons          79.0   154.0   128.0
# 194. Fight with artillery and tanks                    1.0     1.0     8.0
# 195. Employ aerial weapons, not specified below        5.0     4.0     6.0
# 201. Engage in mass expulsion                          NaN     NaN     NaN
# 202. Engage in mass killings                           NaN     1.0     NaN
# 203. Engage in ethnic cleansing                        NaN     1.0     NaN
#
# Year                                                  2015    2016    2017
# Description
# 010. Make statement, not specified below            4594.0  4985.0  4009.0
# 011. Decline comment                                  93.0    78.0    72.0
# 012. Make pessimistic comment                        857.0   970.0   718.0
# 013. Make optimistic comment                        1230.0  1430.0  1071.0
# 014. Consider policy option                          625.0   581.0   395.0
# 015. Acknowledge or claim responsibility             211.0   324.0   219.0
# 016. Deny responsibility                              99.0   114.0    81.0
# 017. Engage in symbolic act                         1125.0   569.0   361.0
# 018. Make empathetic comment                         585.0   243.0    92.0
# 019. Express accord                                    9.0     8.0     9.0
# 020. Make an appeal or request, not specified b...  3591.0  3997.0  3228.0
# 021. Appeal for material cooperation, not speci...    10.0     7.0     8.0
# 0211. Appeal for economic cooperation                 26.0    25.0    15.0
# 0213. Appeal for judicial cooperation                  2.0     5.0     5.0
# 0214. Appeal for intelligence                         18.0    52.0    16.0
# 022. Appeal for diplomatic cooperation (such as...    65.0    64.0    37.0
# 023. Appeal for aid, not specified below              92.0    93.0    59.0
# 0231. Appeal for economic aid                         43.0    60.0    31.0
# 0232. Appeal for military aid                          4.0     1.0     5.0
# 0233. Appeal for humanitarian aid                      2.0     6.0    10.0
# 0234. Appeal for military protection or peaceke...     9.0    13.0     1.0
# 024. Appeal for political reform, not specified...     5.0     2.0     2.0
# 0241. Appeal for change in leadership                 21.0    18.0     9.0
# 0242. Appeal for policy change                         NaN     NaN     NaN
# 0243. Appeal for rights                                1.0     NaN     2.0
# 0244. Appeal for change in institutions, regime        2.0     1.0     NaN
# 025. Appeal to yield, not specified below             78.0    72.0    56.0
# 0251. Appeal for easing of administrative sanct...     NaN     NaN     NaN
# 0253. Appeal for release of persons or property        8.0     3.0     3.0
# 0254. Appeal for easing of economic sanctions, ...     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# 1711. Confiscate property                             22.0    60.0     7.0
# 1712. Destroy property                                84.0    72.0    78.0
# 172. Impose administrative sanctions, not speci...   596.0   750.0   709.0
# 1721. Impose restrictions on political freedoms       39.0    78.0    37.0
# 1722. Ban political parties or politicians             8.0     3.0     5.0
# 1723. Impose curfew                                   22.0    24.0    17.0
# 1724. Impose state of emergency or martial law         5.0     1.0     NaN
# 173. Arrest, detain, or charge with legal action    1707.0  2495.0  1774.0
# 174. Expel or deport individuals                      71.0   127.0    83.0
# 175. Use tactics of violent repression                 3.0     4.0     4.0
# 180. Use unconventional violence, not specified...    93.0   116.0   165.0
# 181. Abduct, hijack, or take hostage                  31.0    47.0    38.0
# 182. Physically assault, not specified below          61.0    81.0    90.0
# 1821. Sexually assault                                28.0    79.0    59.0
# 1822. Torture                                         11.0     9.0     7.0
# 1823. Kill by physical assault                        10.0     6.0     4.0
# 183. Conduct suicide, car, or other non-militar...    17.0     6.0     8.0
# 1831. Carry out suicide bombing                        NaN     2.0     NaN
# 1832. Carry out vehicular bombing                      2.0     NaN     NaN
# 185. Attempt to assassinate                            1.0     2.0     NaN
# 186. Assassinate                                      92.0    92.0    56.0
# 190. Use conventional military force, not speci...   956.0  1111.0   868.0
# 191. Impose blockade, restrict movement               20.0    30.0    24.0
# 192. Occupy territory                                268.0   302.0   236.0
# 193. Fight with small arms and light weapons         257.0   349.0   207.0
# 194. Fight with artillery and tanks                    5.0   136.0    42.0
# 195. Employ aerial weapons, not specified below       47.0    42.0    21.0
# 201. Engage in mass expulsion                          NaN     NaN     1.0
# 202. Engage in mass killings                           4.0     1.0     NaN
# 203. Engage in ethnic cleansing                        2.0     1.0     2.0
#
# [212 rows x 15 columns]

# %% [markdown]
# #### 2. Annual AvgTone Data

# %%
rekap_akhir = run("""
SELECT 
    Year, 
    count(a.GLOBALEVENTID) as `Total Events`, 
    sum(CASE WHEN AvgTone > 0 THEN 1 ELSE 0 END) as `Total +AvgTone`,
    sum(CASE WHEN AvgTone < 0 THEN 1 ELSE 0 END) as `Total -AvgTone`,    
    sum(CASE WHEN AvgTone = 0 THEN 1 ELSE 0 END) as `Total Netral AvgTone`,    
    avg(AvgTone) as `AvgTone`,
    avg(CASE WHEN AvgTone > 0 THEN AvgTone ELSE 0 END) as `+AvgTone`,
    avg(CASE WHEN AvgTone < 0 THEN AvgTone ELSE 0 END) as `-AvgTone`,    
    (sum(AvgTone * NumArticles)/sum(NumArticles)) as `Weighted AvgTone`    
FROM {} a GROUP BY Year ORDER BY Year
  """.format(table_name))

# max(case when AvgTone >= 0 then AvgTone end) max_positive,
# max(case when AvgTone < 0 then AvgTone end) max_negative
rekap_akhir.to_csv('rekap' + fips_country_code + '.csv')
rekap_akhir
# Out:
#     Year  Total Events  Total +AvgTone  Total -AvgTone  Total Netral AvgTone  \
# 0   2003          5272          5257.0             0.0                  15.0
# 1   2004          3748          3726.0             0.0                  22.0
# 2   2005          3202          3187.0             2.0                  13.0
# 3   2006          5502          5474.0             6.0                  22.0
# 4   2007          9927          9896.0             6.0                  25.0
# 5   2008         12120         12065.0             6.0                  49.0
# 6   2009         22541         22443.0             0.0                  98.0
# 7   2010         20164         20074.0             0.0                  90.0
# 8   2011         26774         26643.0             0.0                 131.0
# 9   2012         28202         27978.0             0.0                 224.0
# 10  2013         28208         27297.0             0.0                 911.0
# 11  2014         35281         33871.0           376.0                1034.0
# 12  2015         57780         32926.0         23397.0                1457.0
# 13  2016         62403         30123.0         30701.0                1579.0
# 14  2017         49594         24704.0         23702.0                1188.0
#
#      AvgTone  +AvgTone  -AvgTone  Weighted AvgTone
# 0   5.178416  5.178416  0.000000          5.231622
# 1   5.633898  5.633898  0.000000          5.669425
# 2   5.638027  5.639051 -0.001024          5.753622
# 3   5.865593  5.868297 -0.002704          5.786742
# 4   5.853913  5.856664 -0.002751          5.846894
# 5   5.707397  5.709292 -0.001896          5.729746
# 6   5.878210  5.878210  0.000000          5.707109
# 7   5.772410  5.772410  0.000000          4.871157
# 8   5.928571  5.928571  0.000000          5.595367
# 9   5.582428  5.582428  0.000000          5.260112
# 10  2.737989  2.737989  0.000000          2.643140
# 11  2.673599  2.706655 -0.033056          2.465986
# 12  0.171880  1.424317 -1.252437         -0.361534
# 13 -0.495767  1.166835 -1.662601         -1.330647
# 14 -0.400748  1.238589 -1.639337         -1.358766
